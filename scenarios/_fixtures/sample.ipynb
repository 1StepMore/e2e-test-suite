# %% [markdown]
# # Sample Notebook
#
# This is a sample notebook for testing.

# %%
print('Hello World')

# %% [markdown]
# ## Section 2
#
# More markdown content.

# %%
x = 42
y = 100
# Out:
# 42
# 100
